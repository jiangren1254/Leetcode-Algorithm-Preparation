# %% [markdown]
# 11111111111

# %% [markdown]
# 2222222

# %%
def main():
    # T = int(input())
    T = 3
    for _ in range(T):
        # n = int(input())
        # d = list(map(int, input().split()))
        n = 7
        array = [4, 0, 0, 1, 3, 1, 3,]
        print(n, array)
        # 现在di= 0位上建立服务点。
        intervals = []
        for i in range(n):
            L = max(1,i+1-array[i])
            R = min(n,i+1+array[i])
            intervals.append((L,R))
        intervals.sort(key=lambda x:x[1])
        print(intervals)
        result, last_node = 0, -1
        for L,R in intervals:
            if last_node < L:
                result += 1
                last_node = R
        print(result)

        break

main()

# 3
# 7
# 4 0 0 1 3 1 3
# 5
# 0 1 1 1 0
# 4
# 0 0 0 0
# Out:
# 7 [4, 0, 0, 1, 3, 1, 3]
# [(2, 2), (3, 3), (1, 5), (3, 5), (2, 7), (5, 7), (4, 7)]
# 3

# %%
MOD = 10**9 + 7
def get_good_number(n):
    if n == 1:
        return False
    # 分解
    tmp = n
    upper = int(tmp**0.5)
    totals = 0
    last_tmp = -1
    for i in range(2, upper+1):
        # print(i)

        if tmp % i == 0:
            totals = (totals+i)% MOD
            while tmp % i == 0:
                tmp = tmp // i
        if tmp == last_tmp:
            break
        # print(tmp)
        last_tmp = tmp
    # print(tmp)
    if tmp > 1:
        totals += tmp
    print(totals)
    return  totals % 2

if get_good_number(123456789):
    print("YES")
else:
    print("NO")
# Out:
# 13717424
# NO

# %%
'az'<'zz'
# Out:
# True

# %%
MOD = 10**9 +7
def get_good_number(n):
    if n == 1:
        return False
    # 分解
    tmp = n
    upper = int(tmp**0.5)
    totals = 0
    last_tmp = -1
    for i in range(2, upper+1):
        # 判断所有的值。
        if tmp % i == 0:
            totals = (totals+i)% MOD
            while tmp % i == 0:
                tmp = tmp // i
        # if tmp == last_tmp:
        #     break
        last_tmp = tmp
    # print(tmp)
    if tmp > 1:
        totals += tmp
    # print(totals)
    return  totals % 2


def main():
    # T = int(input().strip())
    # for _ in range(T):
    #     n = int(input().strip())
    n = 12
    if get_good_number(n):
        print("YES")
    else:
        print("NO")

main()
# Out:
# YES
