# %% [markdown]
# 11111111

# %%
sum([1,2,3,4,5]) % 2
# Out:
# 1

# %%
def main():
    # n,m = map(int, input().split())
    # array = list(map(int,input().split()))
    array =[1,2,3,4,5]
    it = iter(array)
    for _ in range(5):
        print(next(it))
    # for _ in range(m):
    #     pass
    
main()
# Out:
# 1
# 2
# 3
# 4
# 5
