# %% [markdown]
# 每天刷2小时就可以，上午1小时，下午1小时，主要是保证刷题手感
#
# [algorithm-pattern-python github 链接](https://github.com/dashidhy/algorithm-pattern-python)
#
# 一点点往前刷，一定要结合 [hello-algo_1.2.0_zh_python](../hello-algo_1.2.0_zh_python.pdf)  这本书
#
# [力扣hot100 高频考查题 ](https://codetop.cc/home)
#
#
#
# > 如何检验自己是否掌握了这个题？
# > 看懂别人的答案后，一定要不借助任何提示，不卡顿的学出代码才算过关，有任何卡顿都要重新写。并且把卡住的地方总结带笔记里面

# %% [markdown]
# # 进度管理

# %% [markdown]
# - 2025-8-1 学习内容：
#   - [01使用 Python3 写算法题](./algorithm-pattern-python/01使用%20Python3%20写算法题.ipynb)
#     - 常用特性 数组初始化，
#     - 标准算法 sorted() 和 .sort()
#     - 标准数据结构 栈，队列，最小堆
#
# - 2025-8-2 学习内容：
#   - [02快速开始](./algorithm-pattern-python/02快速开始.ipynb)
#     - 28. 找出字符串中第一个匹配项的下标。在干草堆里找针
#     - 78. 子集。回朔法：全排列问题
#
# ---

# %% [markdown]
# - 2025-8-4 学习内容：
#   - [03二叉树](./algorithm-pattern-python/03二叉树.ipynb)
#       - 二叉树的前、中、后序遍历，递归和迭代共六套代码
#       - 层序遍历
#       - 二叉树的最大深度：分治法
#       - 判断一棵树是否为平衡二叉树
#       - 看到了使用后序遍历(左->右->根)实现分治法的迭代版本解决平衡二叉树问题
#
#
# - 2025-8-5 学习内容：
#   - [03二叉树](./algorithm-pattern-python/03二叉树.ipynb)
#     - 掌握了二叉树中的，分治法
#     - 104. 二叉树的最大深度
#     - 10. 平衡二叉树
#     - 124. 二叉树中的最大路径和
#     - 236. 二叉树的最近公共祖先
#     - 103. 二叉树的锯齿形层序遍历
#     - 98. 验证二叉搜索树
#     - 701. 二叉搜索树中的插入操作
#
# - 2025-08-23 学习内容：
#   - [03二叉树](./algorithm-pattern-python/03二叉树.ipynb)
#     - 面试中被了回朔法“子集问题”
#     - 掌握了前序遍历非递归，未掌握中序和后序非递归写法
#   - [04链表](./algorithm-pattern-python/04链表.ipynb),
#     - 刷了模版中的前六个题，remove duplicate,1,2、reverse list 局部，全局、merge list、 partition list
#     -
#
# - 2025-08-24 学习内容：
#   - [04链表](./algorithm-pattern-python/04链表.ipynb),
#     -  归并排序：分治、找中点、合并两个有序链表；
#     -  reorder-list,找中点，反转后面的半部分，在原地修改
#     -  sort-list 和 reorder-list
#     -  linked-list-cycle,linked-list-cycle-ii
#     -  palindrome-linked-list，回文链表, 栈数据结构，有很多回文题
#     -  copy-list-with-random-pointer, 思路：复制结点跟在原结点后面，间接维护连接关系，优化空间复杂度，建立好新 list 的 random 链接后分离
#   - [05栈和队列](./algorithm-pattern-python/05栈和队列.ipynb)
#     -  min-stack, 栈的增删查
#     -  “计算逆波兰表达式”, 利用栈后入先出的特性  evaluate-reverse-polish-notation
#     -  decode-string, 将元素压入栈，遇到']'解码
#     -  二叉树中序遍历，迭代实现，利用栈,牢记 左、根、右
#     -  clone-graph, 图掌握的不太好，后面还需要练
#     -  number-of-islands，思路：通过深度搜索遍历可能性（注意标记已访问元素）
#
# - 2025-08-25 学习内容：
#   - [05栈和队列](./algorithm-pattern-python/05栈和队列.ipynb)
#     - number-of-islands，思路：通过深度搜索遍历可能性（注意标记已访问元素）
#     - largest-rectangle-in-histogram, 在柱状体中最大的矩形。包含当前 bar 最大矩形的边界为左边第一个高度小于当前高度的 bar 和右边第一个高度小于当前高度的 bar。
#     - 队列，常用于 BFS 宽度优先搜索，implement-queue-using-stacks，binary-tree-level-order-traversal
#     - 01-matrix，从 0 开始 BFS, 遇到距离最小值需要更新的则更新后重新入队更新后续结点
#     - 单调栈和单调队列
#     - 单调栈经典的两个困难题：柱状图中最大的矩形和接雨水
#     - 单调队列经典的两个困难题：滑动窗口最大值， 和至少为 K 的最短子数组（这个没太搞懂）
#   - [06优先级队列(堆)](./06algorithm-pattern-python/优先级队列(堆).ipynb)
#     - 优先级队列的另一个名字叫做堆heap，典型应用第k个最大元素,学会 heapq 的使用
#     - kth-smallest-element-in-a-sorted-matrix, 优先队列做法，没有充分利用有序这个有利条件
#     - find-k-pairs-with-smallest-sums， 和最小的k 对数据
#     - 上面都是top-k问题，都用优先队列
#
# - 2025-08-25 学习内容：
#   - 晚上18：:50，我打算先刷力扣hot100
#
# ---

# %% [markdown]
# - 2025-08-26 学习内容：
#   - [06优先级队列(堆)](./algorithm-pattern-python/06优先级队列(堆).ipynb)
#     - Greedy + Heap 4个题；Prim's Algorithm 1个题；Dijkstra's Algorithm 2个题
#     - maximum-performance-of-a-team, 看上起很难
#     - IPO 指的是现实世界中的 Initial Public Offering（首次公开募股）
#     - meeting-rooms-ii
#     - reorganize-string
#     - Prim’s Algorithm（普里姆算法）是一种 最小生成树（Minimum Spanning Tree, MST）算法。
#     - Dijkstra's Algorithm,实现上是 greedy + heap 的一个应用，用于求解图的单源最短路径相关的问题，生成的树为最短路径树 (SPT)。
#       - networkDelayTime
#       - cheapest-flights-within-k-stops
#   - [并查集](./algorithm-pattern-python/07并查集.ipynb)
#     - 四个题
#     - redundant-connection，冗余连接
#     - accounts-merge, 账户合并, 和冗余连接的并查集一样
#     - longest-consecutive-sequence，最长的连续序列
#     - 克鲁斯卡尔（kruskal）算法通常用于求出一个连通图中的最小生成树，需要会员
#   - [二进制](./algorithm-pattern-python/08二进制.ipynb)
#     - 7个题, 全程是算法题中的二进制操作，也叫位运算
#     - single number 1,2,3
#     - number-of-1-bits, 也叫汉明重量
# - 2025-08-27 学习内容：
#   - [二进制](./algorithm-pattern-python/08二进制.ipynb)
#     - counting-bits
#     - reverse-bits
#     - bitwise-and-of-numbers-range
#   - [二分搜索和排序算法](./algorithm-pattern-python/09二分搜索和排序算法.ipynb)
#     - 一共9个题。
#     - binary-search，模版1,2,3
#     - find-first-and-last-position-of-element-in-sorted-array 和 search-insert-position
#     - search-a-2d-matrix，用模版1，模版2有点坑，left和right在查询值最大的时候会出届
#     - find-minimum-in-rotated-sorted-array，使用二分搜索，当中间元素大于右侧元素时意味着拐点即最小元素在右侧，否则在左侧
#     - find-minimum-in-rotated-sorted-array-ii。相比上面的题，加入了重复元素。直觉是先去重，看看别人的好方法！
#     - rotated-sorted-array 旋转排序数组的题有四个，两个找到最小值，两个找到目标值。
#     - search-in-rotated-sorted-array-ii，加入了重复元素, 相比于前面的代码，只加了重复值判断
#     - koko-eating-bananas 隐藏的二分搜索
#
# - 2025-08-28 学习内容：
#   - [二分搜索和排序算法](./algorithm-pattern-python/09二分搜索和排序算法.ipynb)
#     -  快排、归并、堆。可以手写快排、归并、堆排序
#     -  归并排序：findMid(list),mergeList(list1,list2), 递归左边，递归右边，递归出口是len(nums) < 2
#     -  快排：哨兵划分，直到子数组长度为1，基准（pivot）取数组最左边。
#     -  堆排序：建立最大堆，循环n-1次（拆堆，建堆）
#     -  和一个快速选择的题，kth-largest-element-in-an-array，用堆做，不用这个快速选择做
#     -  十大经典排序
#
#
# - 2025-08-29 学习内容：
#   -  [10动态规划](./algorithm-pattern-python/10动态规划.ipynb)
#      -  题比较多，足足有15个，背包问题
#      -  120. 三角形最小路径和,triangle, 这个 题能够很好的区分贪心和dp
#      -  1、Matrix DP (10%)
#         -  这种题代表有triangle, 最小路径，unique-paths，unique-paths with-obstacle，DP模版，dp表大小为矩阵列数，状态转移方程式行扫描
#      -  2、序列类型（40%）
#         -  这种题代表是爬楼梯, 买卖股票最佳时期
#         -  jump-game、jump-game-ii、palindrome-partitioning-ii、longest-increasing-subsequence(常考)
#         -  word-break
#      -  3、two Sequences DP (40%)
#         -  edit-distance，今天领岳科技笔试题, 这个暂时不理解，可以先写成空间不优化版进行学习
#         -  longest-common-subsequence
#      -  4、Backpack (10%)
#         -  322. 零钱兑换: 感觉就是二维dp, 就是更新的时候有段差别
#         -  背包问题，0-1背包，学完了。完全背包还没学习
#      -  补充
#         -  152. 乘积最大子数组、91.  解码方法 等5个补充题
#         -  补充题战术不看了
#
# - 2025-08-31 学习内容：
#   -  [11图相关算法](./algorithm-pattern-python/11图相关算法.ipynb)
#      -  图的先不看了
#
#
# ---

# %% [markdown]
# - 2025-9-1 学习内容：
#   - [12递归思维和滑动窗口思想](./algorithm-pattern-python/12递归思维和滑动窗口思想.ipynb)
#     - 344. 反转字符串：s[::-1]  or 递归, 这题最优是双指针
#     - 24. 两两交换链表中的节点
#     - 95. 不同的二叉搜索树 II
#     - 509. 斐波那契数
#     - 滑动窗口
#     - 76. 最小覆盖子串
#     - 567. 字符串的排列
#     - 438. 找到字符串中所有字母异位词
#     - 3. 无重复字符的最长子串
#
# - 2025-9-2 学习内容：
#   - [13二叉搜索树](./algorithm-pattern-python/13二叉搜索树.ipynb)
#     - 98. 验证二叉搜索树
#     - 701. 二叉搜索树中的插入操作
#     - 450. 删除二叉搜索树中的节点
#     - 110. 平衡二叉树
#     - valid-bfs-of-bst, 面试真题
#
# - 2025-9-3 学习内容：
#   - [14回溯](./algorithm-pattern-python/14回溯.ipynb)
#     - 全排列、子集和、n皇后
#     - 78. 子集
#     - 90. 子集 II, 相比于上个题，nums中有重复元素
#     - 46. 全排列
#     - 47. 全排列 II
#     - 39. 组合总和
#     - 17. 电话号码的字母组合
#     - 131. 分割回文串
#     - 93. 复原 IP 地址
#
# ---
